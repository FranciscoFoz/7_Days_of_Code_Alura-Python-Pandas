# %% [markdown]
# <a href="https://colab.research.google.com/github/FranciscoFoz/7_Days_of_Code_Alura-Python-Pandas/blob/main/Dia_7-Apresentando_resultados_em_HTML/Dia_7_Apresentando_resultados_em_HTML.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Dia 1 - Importação de dados

# %%
import pandas as pd

# %%
dados_2010_1 = pd.read_csv('https://dados.ufrn.br/dataset/1e596793-1ac3-4b59-9ae8-f053eda6b698/resource/36a2c54d-0ed6-46bd-a3e9-161c39c0eac6/download/emprestimos-20101.csv',sep=';')
dados_2010_2 = pd.read_csv('https://dados.ufrn.br/dataset/1e596793-1ac3-4b59-9ae8-f053eda6b698/resource/b954b071-5d8f-43d0-b956-e47c9922cc1a/download/emprestimos-20102.csv',sep=';')
dados_2011_1 = pd.read_csv('https://dados.ufrn.br/dataset/1e596793-1ac3-4b59-9ae8-f053eda6b698/resource/bae6ed0a-9430-4d5c-9b90-72ffe6e023df/download/emprestimos-20111.csv',sep=';')
dados_2011_2 = pd.read_csv('https://dados.ufrn.br/dataset/1e596793-1ac3-4b59-9ae8-f053eda6b698/resource/629c232f-7249-4dbd-8928-0c53af7e9b2a/download/emprestimos-20112.csv',sep=';')
dados_2012_1 = pd.read_csv('https://dados.ufrn.br/dataset/1e596793-1ac3-4b59-9ae8-f053eda6b698/resource/f9540095-6894-4ffa-b10d-b0ffbb17aa5f/download/emprestimos-20121.csv',sep=';')
dados_2012_2 = pd.read_csv('https://dados.ufrn.br/dataset/1e596793-1ac3-4b59-9ae8-f053eda6b698/resource/7bec7701-0778-43f8-a327-540c6ec94fb6/download/emprestimos-20122.csv',sep=';')
dados_2013_1 = pd.read_csv('https://dados.ufrn.br/dataset/1e596793-1ac3-4b59-9ae8-f053eda6b698/resource/c54c4556-1ca2-4918-963d-f066082e4ee0/download/emprestimos-20131.csv',sep=';')
dados_2013_2 = pd.read_csv('https://dados.ufrn.br/dataset/1e596793-1ac3-4b59-9ae8-f053eda6b698/resource/043d7156-67e9-4492-9ec7-8b7353b47bfa/download/emprestimos-20132.csv',sep=';')
dados_2014_1 = pd.read_csv('https://dados.ufrn.br/dataset/1e596793-1ac3-4b59-9ae8-f053eda6b698/resource/8e97f632-a6fe-4349-b06b-f650e804a7b9/download/emprestimos-20141.csv',sep=';')
dados_2014_2 = pd.read_csv('https://dados.ufrn.br/dataset/1e596793-1ac3-4b59-9ae8-f053eda6b698/resource/832df6b3-ccb0-4370-832b-193a2fe90085/download/emprestimos-20142.csv',sep=';')
dados_2015_1 = pd.read_csv('https://dados.ufrn.br/dataset/1e596793-1ac3-4b59-9ae8-f053eda6b698/resource/2d18b7a9-b458-4668-8858-037c55049d40/download/emprestimos-20151.csv',sep=';')
dados_2015_2 = pd.read_csv('https://dados.ufrn.br/dataset/1e596793-1ac3-4b59-9ae8-f053eda6b698/resource/f07e4501-8632-487f-adf0-116d5b6fb4fe/download/emprestimos-20152.csv',sep=';')
dados_2016_1 = pd.read_csv('https://dados.ufrn.br/dataset/1e596793-1ac3-4b59-9ae8-f053eda6b698/resource/17955462-aa54-45c7-9820-e9ab7d128be4/download/emprestimos-20161.csv',sep=';')
dados_2016_2 = pd.read_csv('https://dados.ufrn.br/dataset/1e596793-1ac3-4b59-9ae8-f053eda6b698/resource/04ed856a-c6bd-4c67-a08b-ad7f382dcd7e/download/emprestimos-20162.csv',sep=';')
dados_2017_1 = pd.read_csv('https://dados.ufrn.br/dataset/1e596793-1ac3-4b59-9ae8-f053eda6b698/resource/54f56d6f-a5cc-41d9-88d6-4f4292fe26bc/download/emprestimos-20171.csv',sep=';')
dados_2017_2 = pd.read_csv('https://dados.ufrn.br/dataset/1e596793-1ac3-4b59-9ae8-f053eda6b698/resource/79d668de-5d2a-4c1e-ad62-5f2933d36600/download/emprestimos-20172.csv',sep=';')
dados_2018_1 = pd.read_csv('https://dados.ufrn.br/dataset/1e596793-1ac3-4b59-9ae8-f053eda6b698/resource/5cac670e-a90f-4ba3-95f5-65b7d82a538a/download/emprestimos-20181.csv',sep=';')
dados_2018_2 = pd.read_csv('https://dados.ufrn.br/dataset/1e596793-1ac3-4b59-9ae8-f053eda6b698/resource/02a9e1d6-900c-450e-8e8f-90fac8125a96/download/emprestimos-20182.csv',sep=';')
dados_2019_1 = pd.read_csv('https://dados.ufrn.br/dataset/1e596793-1ac3-4b59-9ae8-f053eda6b698/resource/66f1737b-5732-4029-8b22-2698be3e24ca/download/emprestimos-20191.csv',sep=';')
dados_2019_2 = pd.read_csv('https://dados.ufrn.br/dataset/1e596793-1ac3-4b59-9ae8-f053eda6b698/resource/51786bd8-e61c-4e4d-8ff9-51602f4e37e3/download/emprestimos-20192.csv',sep=';')
dados_2020_1 = pd.read_csv('https://dados.ufrn.br/dataset/1e596793-1ac3-4b59-9ae8-f053eda6b698/resource/c7e609a6-0daf-449b-8564-1876be6e69d5/download/emprestimos-20201.csv',sep=';')

# %%
emprestimos_biblioteca = pd.concat([dados_2010_1,dados_2010_2,dados_2011_1,dados_2011_2,dados_2012_1,dados_2012_2,dados_2013_1,dados_2013_2,dados_2014_1,
                                    dados_2014_2,dados_2015_1,dados_2015_2,dados_2016_1,dados_2016_2,dados_2017_1,dados_2017_2,dados_2018_1,dados_2018_2,
                                    dados_2019_1,dados_2019_2,dados_2020_1],ignore_index=True)
emprestimos_biblioteca
# Out:
#          id_emprestimo codigo_barras                 data_renovacao  \
# 0               709684       L095049                            NaN
# 1               709685       L167050                            NaN
# 2               709686    2006017618  2010/01/26 08:07:01.738000000
# 3               709687       L184117  2010/01/18 11:07:46.470000000
# 4               709688    2007027500  2010/01/19 15:59:26.464000000
# ...                ...           ...                            ...
# 2257976        2989086    2008047044                            NaN
# 2257977        2989087    2008047047                            NaN
# 2257978        2989088    2010052905                            NaN
# 2257979        2989089    2010048023                            NaN
# 2257980        2989090    2013106838                            NaN
#
#                        data_emprestimo                 data_devolucao  \
# 0        2010/01/04 07:44:10.721000000  2010/01/05 16:26:12.662000000
# ...

# %%
emprestimos_biblioteca.value_counts()
# Out:
# id_emprestimo  codigo_barras  data_renovacao                 data_emprestimo                data_devolucao                 matricula_ou_siape  nome_usuario                                tipo_vinculo_usuario
# 2433391        2013109357     2017/05/22 23:14:56.152000000  2017/05/08 14:46:55.784000000  2017/06/06 18:40:23.000000000  2.016019e+09        KLYFTON STANLEY FERNANDES DA SILVA QUEIROZ  ALUNO DE GRADUAÇÃO        2
# 2384297        2009036111     2017/03/27 10:36:05.024000000  2017/03/09 12:09:38.663000000  2017/04/20 14:07:26.000000000  2.015400e+10        VANESSA DE PAIVA MELO                       ALUNO DE PÓS-GRADUAÇÃO    2
# 2384292        2013077602     2017/03/22 08:49:02.962000000  2017/03/09 12:04:50.106000000  2017/04/10 16:50:18.000000000  2.017014e+10        ISABELA AZEVEDO MEDEIROS DO NASCIMENTO      ALUNO DE GRADUAÇÃO        2
# ...

# %%
emprestimos_biblioteca = emprestimos_biblioteca.drop_duplicates()

# %%
emprestimos_biblioteca.head()
# Out:
#    id_emprestimo codigo_barras                 data_renovacao  \
# 0         709684       L095049                            NaN
# 1         709685       L167050                            NaN
# 2         709686    2006017618  2010/01/26 08:07:01.738000000
# 3         709687       L184117  2010/01/18 11:07:46.470000000
# 4         709688    2007027500  2010/01/19 15:59:26.464000000
#
#                  data_emprestimo                 data_devolucao  \
# 0  2010/01/04 07:44:10.721000000  2010/01/05 16:26:12.662000000
# 1  2010/01/04 07:44:10.750000000  2010/01/12 07:34:13.934000000
# 2  2010/01/04 08:08:44.081000000  2010/02/25 07:36:25.800000000
# 3  2010/01/04 08:24:21.284000000  2010/02/03 08:58:45.692000000
# 4  2010/01/04 08:27:33.569000000  2010/02/03 13:06:30.662000000
#
#    matricula_ou_siape                      nome_usuario  \
# 0        2.008023e+09  CARLOS EDUARDO DE ARAÚJO PADILHA
# 1        2.008023e+09  CARLOS EDUARDO DE ARAÚJO PADILHA
# ...

# %%
dados_exemplares = pd.read_parquet('https://github.com/FranciscoFoz/7_Days_of_Code_Alura-Python-Pandas/raw/main/Dia_1-Importando_dados/Datasets/dados_exemplares.parquet')
dados_exemplares
# Out:
#         id_exemplar codigo_barras             colecao  \
# 0                 5       L000003   Acervo Circulante
# 1                 4       L000002   Acervo Circulante
# 2                 3       L000001   Acervo Circulante
# 3                 7       L000114   Acervo Circulante
# 4                 9       L000040  Acervo de Desbaste
# ...             ...           ...                 ...
# 568580      1353472    2021011150   Acervo Circulante
# 568581      1353473    2019013454   Acervo Circulante
# 568582      1353474    2019012811   Acervo Circulante
# 568583      1353475    2019013451   Acervo Circulante
# 568584      1353476    2019012276   Acervo Circulante
#
#                                                biblioteca status_material  \
# 0                          Biblioteca Central Zila Mamede         REGULAR
# 1                          Biblioteca Central Zila Mamede         REGULAR
# 2                          Biblioteca Central Zila Mamede        ESPECIAL
# ...

# %% [markdown]
# #Dia 2 - As primeiras manipulações

# %%
import pandas as pd

# %%
emprestimos_biblioteca
# Out:
#          id_emprestimo codigo_barras                 data_renovacao  \
# 0               709684       L095049                            NaN
# 1               709685       L167050                            NaN
# 2               709686    2006017618  2010/01/26 08:07:01.738000000
# 3               709687       L184117  2010/01/18 11:07:46.470000000
# 4               709688    2007027500  2010/01/19 15:59:26.464000000
# ...                ...           ...                            ...
# 2257976        2989086    2008047044                            NaN
# 2257977        2989087    2008047047                            NaN
# 2257978        2989088    2010052905                            NaN
# 2257979        2989089    2010048023                            NaN
# 2257980        2989090    2013106838                            NaN
#
#                        data_emprestimo                 data_devolucao  \
# 0        2010/01/04 07:44:10.721000000  2010/01/05 16:26:12.662000000
# ...

# %%
dados_exemplares
# Out:
#         id_exemplar codigo_barras             colecao  \
# 0                 5       L000003   Acervo Circulante
# 1                 4       L000002   Acervo Circulante
# 2                 3       L000001   Acervo Circulante
# 3                 7       L000114   Acervo Circulante
# 4                 9       L000040  Acervo de Desbaste
# ...             ...           ...                 ...
# 568580      1353472    2021011150   Acervo Circulante
# 568581      1353473    2019013454   Acervo Circulante
# 568582      1353474    2019012811   Acervo Circulante
# 568583      1353475    2019013451   Acervo Circulante
# 568584      1353476    2019012276   Acervo Circulante
#
#                                                biblioteca status_material  \
# 0                          Biblioteca Central Zila Mamede         REGULAR
# 1                          Biblioteca Central Zila Mamede         REGULAR
# 2                          Biblioteca Central Zila Mamede        ESPECIAL
# ...

# %%
emprestimos_completo = emprestimos_biblioteca.merge(dados_exemplares,'left')
emprestimos_completo
# Out:
#          id_emprestimo codigo_barras                 data_renovacao  \
# 0               709684       L095049                            NaN
# 1               709685       L167050                            NaN
# 2               709686    2006017618  2010/01/26 08:07:01.738000000
# 3               709687       L184117  2010/01/18 11:07:46.470000000
# 4               709688    2007027500  2010/01/19 15:59:26.464000000
# ...                ...           ...                            ...
# 2142801        2989086    2008047044                            NaN
# 2142802        2989087    2008047047                            NaN
# 2142803        2989088    2010052905                            NaN
# 2142804        2989089    2010048023                            NaN
# 2142805        2989090    2013106838                            NaN
#
#                        data_emprestimo                 data_devolucao  \
# 0        2010/01/04 07:44:10.721000000  2010/01/05 16:26:12.662000000
# ...

# %%
emprestimos_completo = emprestimos_completo.drop(columns=['nome_usuario','registro_sistema'])
emprestimos_completo
# Out:
#          id_emprestimo codigo_barras                 data_renovacao  \
# 0               709684       L095049                            NaN
# 1               709685       L167050                            NaN
# 2               709686    2006017618  2010/01/26 08:07:01.738000000
# 3               709687       L184117  2010/01/18 11:07:46.470000000
# 4               709688    2007027500  2010/01/19 15:59:26.464000000
# ...                ...           ...                            ...
# 2142801        2989086    2008047044                            NaN
# 2142802        2989087    2008047047                            NaN
# 2142803        2989088    2010052905                            NaN
# 2142804        2989089    2010048023                            NaN
# 2142805        2989090    2013106838                            NaN
#
#                        data_emprestimo                 data_devolucao  \
# 0        2010/01/04 07:44:10.721000000  2010/01/05 16:26:12.662000000
# ...

# %%
emprestimos_completo['matricula_ou_siape'] = emprestimos_completo['matricula_ou_siape'].astype('string')

# %%
CDU_lista = []
for CDU in emprestimos_completo['localizacao']:
  if(CDU < 100):
    CDU_lista.append('Generalidades')
  elif(CDU < 200):
    CDU_lista.append('Filosofia e psicologia')
  elif(CDU < 300):
    CDU_lista.append('Religião')
  elif(CDU < 400):
    CDU_lista.append('Ciências sociais')
  elif(CDU < 500):
    CDU_lista.append('Classe vaga')
  elif(CDU < 600):
    CDU_lista.append('Matemática e ciências naturais')
  elif(CDU < 700):
    CDU_lista.append('Ciências aplicadas')
  elif(CDU < 800):
    CDU_lista.append('Belas artes')
  elif(CDU < 900):
    CDU_lista.append('Linguagem')
  else:
    CDU_lista.append('Geografia. Biografia. História.')

emprestimos_completo['CDU_geral'] = CDU_lista

# %%
emprestimos_completo['CDU_geral'] = CDU_lista

# %%
emprestimos_completo.head()
# Out:
#    id_emprestimo codigo_barras                 data_renovacao  \
# 0         709684       L095049                            NaN
# 1         709685       L167050                            NaN
# 2         709686    2006017618  2010/01/26 08:07:01.738000000
# 3         709687       L184117  2010/01/18 11:07:46.470000000
# 4         709688    2007027500  2010/01/19 15:59:26.464000000
#
#                  data_emprestimo                 data_devolucao  \
# 0  2010/01/04 07:44:10.721000000  2010/01/05 16:26:12.662000000
# 1  2010/01/04 07:44:10.750000000  2010/01/12 07:34:13.934000000
# 2  2010/01/04 08:08:44.081000000  2010/02/25 07:36:25.800000000
# 3  2010/01/04 08:24:21.284000000  2010/02/03 08:58:45.692000000
# 4  2010/01/04 08:27:33.569000000  2010/02/03 13:06:30.662000000
#
#   matricula_ou_siape    tipo_vinculo_usuario  id_exemplar            colecao  \
# 0       2008023265.0      ALUNO DE GRADUAÇÃO      13259.0  Acervo Circulante
# ...

# %% [markdown]
# # Dia 3 - Explorando o Datetime dos dados

# %%
import pandas as pd

# %%
emprestimos_completo
# Out:
#          id_emprestimo codigo_barras                 data_renovacao  \
# 0               709684       L095049                            NaN
# 1               709685       L167050                            NaN
# 2               709686    2006017618  2010/01/26 08:07:01.738000000
# 3               709687       L184117  2010/01/18 11:07:46.470000000
# 4               709688    2007027500  2010/01/19 15:59:26.464000000
# ...                ...           ...                            ...
# 2142801        2989086    2008047044                            NaN
# 2142802        2989087    2008047047                            NaN
# 2142803        2989088    2010052905                            NaN
# 2142804        2989089    2010048023                            NaN
# 2142805        2989090    2013106838                            NaN
#
#                        data_emprestimo                 data_devolucao  \
# 0        2010/01/04 07:44:10.721000000  2010/01/05 16:26:12.662000000
# ...

# %%
emprestimos_completo.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2142806 entries, 0 to 2142805
# Data columns (total 13 columns):
#  #   Column                Dtype
# ---  ------                -----
#  0   id_emprestimo         int64
#  1   codigo_barras         object
#  2   data_renovacao        object
#  3   data_emprestimo       object
#  4   data_devolucao        object
#  5   matricula_ou_siape    string
#  6   tipo_vinculo_usuario  object
#  7   id_exemplar           float64
#  8   colecao               object
#  9   biblioteca            object
#  10  status_material       object
#  11  localizacao           float64
#  12  CDU_geral             object
# dtypes: float64(2), int64(1), object(9), string(1)
# memory usage: 228.9+ MB

# %%
emprestimos_completo['tipo_vinculo_usuario'].unique()
# Out:
# array(['ALUNO DE GRADUAÇÃO', 'ALUNO DE PÓS-GRADUAÇÃO', 'DOCENTE',
#        'SERVIDOR TÉCNICO-ADMINISTRATIVO', 'DOCENTE EXTERNO',
#        'ALUNO MÉDIO/TÉCNICO', 'USUÁRIO EXTERNO', 'OUTROS'], dtype=object)

# %%
emprestimos_completo['colecao'].unique()
# Out:
# array(['Acervo Circulante', nan, 'Folhetos', 'Acervo de Desbaste',
#        'Teses', 'Dissertações', 'Monografias',
#        'Publicações de Autores do RN', 'Publicações da UFRN',
#        'Multimeios', 'Coleção Mossoroense', 'Eventos',
#        'Trabalho Acadêmico', 'Obras de Referência', 'Obras Raras',
#        'Literatura de Cordel', 'Coleção Zila Mamede',
#        'Necessidades Educacionais Específicas'], dtype=object)

# %%
emprestimos_completo['biblioteca'].unique()
# Out:
# array(['Biblioteca Central Zila Mamede',
#        'Biblioteca Setorial Prof. Rodolfo Helinski - Escola Agrícola de Jundiaí - EAJ  - Macaiba',
#        'Biblioteca Setorial Bertha Cruz Enders - \xadEscola de Saúde da UFRN - ESUFRN',
#        'Biblioteca Setorial do Centro Ciências da Saúde - CCS', nan,
#        'Biblioteca Setorial Prof. Alberto Moreira Campos - \xadDepartamento de Odontologia',
#        'Biblioteca Setorial Prof. Ronaldo Xavier de Arruda - CCET',
#        'Biblioteca Setorial do Centro de Ciências Humanas, Letras e Artes - CCHLA',
#        'Biblioteca Setorial Dr. Paulo Bezerra - EMCM/RN - Caicó',
#        'Biblioteca Setorial Prof. Horácio Nicolas Solimo - \xad Engenharia Química - EQ - CT',
#        'Biblioteca Setorial Prof. Francisco Gurgel De Azevedo - Instituto Química - IQ',
#        'Biblioteca Setorial do Centro Ciências Sociais Aplicadas - CCSA',
#        'Biblioteca Setorial do Departamento de Artes - DEART',
# ...

# %%
emprestimos_completo['status_material'].unique()
# Out:
# array(['REGULAR', nan, 'ESPECIAL', 'NÃO CIRCULA'], dtype=object)

# %%
emprestimos_completo['id_emprestimo'].value_counts()
# Out:
# 2560028    3
# 2422542    3
# 2014596    3
# 2772079    3
# 2595954    3
#           ..
# 1437859    1
# 1437858    1
# 1437857    1
# 1437856    1
# 2989090    1
# Name: id_emprestimo, Length: 2139267, dtype: int64

# %%
emprestimos_completo.loc[emprestimos_completo['id_emprestimo']==2560028]
# Out:
#          id_emprestimo codigo_barras                 data_renovacao  \
# 1712958        2560028    2010082015  2017/11/22 09:44:18.435000000
# 1712959        2560028    2010082015  2017/11/22 09:44:18.435000000
# 1712960        2560028    2010082015  2017/11/22 09:44:18.435000000
#
#                        data_emprestimo                 data_devolucao  \
# 1712958  2017/11/06 19:52:32.782000000  2017/12/07 19:52:23.000000000
# 1712959  2017/11/06 19:52:32.782000000  2017/12/07 19:52:23.000000000
# 1712960  2017/11/06 19:52:32.782000000  2017/12/07 19:52:23.000000000
#
#         matricula_ou_siape tipo_vinculo_usuario  id_exemplar  \
# 1712958       2015049280.0   ALUNO DE GRADUAÇÃO    1055921.0
# 1712959       2015049280.0   ALUNO DE GRADUAÇÃO    1055569.0
# 1712960       2015049280.0   ALUNO DE GRADUAÇÃO    1056359.0
#
#                    colecao                      biblioteca status_material  \
# 1712958  Acervo Circulante  Biblioteca Central Zila Mamede         REGULAR
# ...

# %%
emprestimos = len(emprestimos_completo['id_emprestimo'].drop_duplicates())
emprestimos
# Out:
# 2139267

# %% [markdown]
# ## Quantos exemplares foram emprestados ao total ?

# %%
exemplares = len(emprestimos_completo)
exemplares
# Out:
# 2142806

# %% [markdown]
# ## Quantos foram por cada ano ?

# %%
emprestimos_data = pd.DataFrame(emprestimos_completo['data_emprestimo'].value_counts()).reset_index()
emprestimos_data.columns = ['data','quantidade']
emprestimos_data['data'] = pd.to_datetime(emprestimos_data['data'])
emprestimos_data
# Out:
#                            data  quantidade
# 0       2010-12-06 00:00:00.000           6
# 1       2010-12-15 00:00:00.000           5
# 2       2010-11-24 00:00:00.000           4
# 3       2010-08-09 16:03:57.373           3
# 4       2015-06-10 18:51:56.994           3
# ...                         ...         ...
# 2139184 2013-03-01 20:26:43.853           1
# 2139185 2013-03-01 20:26:43.806           1
# 2139186 2013-03-01 20:24:56.349           1
# 2139187 2013-03-01 20:23:26.277           1
# 2139188 2020-06-09 11:54:02.852           1
#
# [2139189 rows x 2 columns]

# %%
emprestimos_por_ano = emprestimos_data.groupby(by=emprestimos_data.data.dt.year).sum()
emprestimos_por_ano
# Out:
#       quantidade
# data
# 2010      196147
# 2011      229548
# 2012      250260
# 2013      259599
# 2014      235725
# 2015      225317
# 2016      107405
# 2017      229527
# 2018      202614
# 2019      180028
# 2020       26636

# %%
emprestimos_por_ano['percentual'] = round((emprestimos_por_ano.quantidade / emprestimos_por_ano.quantidade.sum()) * 100, 2)
emprestimos_por_ano
# Out:
#       quantidade  percentual
# data
# 2010      196147        9.15
# 2011      229548       10.71
# 2012      250260       11.68
# 2013      259599       12.11
# 2014      235725       11.00
# 2015      225317       10.52
# 2016      107405        5.01
# 2017      229527       10.71
# 2018      202614        9.46
# 2019      180028        8.40
# 2020       26636        1.24

# %% [markdown]
# ## Quantos foram por cada mês ?

# %%
emprestimos_por_mes = emprestimos_data.groupby(by=emprestimos_data.data.dt.month).sum()
emprestimos_por_mes
# Out:
#       quantidade
# data
# 1          66895
# 2         206206
# 3         246679
# 4         208823
# 5         199245
# 6         133598
# 7         130812
# 8         253100
# 9         227147
# 10        206765
# 11        180909
# 12         82627

# %%
emprestimos_por_mes['percentual'] = round((emprestimos_por_mes.quantidade / emprestimos_por_mes.quantidade.sum()) * 100, 2)
emprestimos_por_mes
# Out:
#       quantidade  percentual
# data
# 1          66895        3.12
# 2         206206        9.62
# 3         246679       11.51
# 4         208823        9.75
# 5         199245        9.30
# 6         133598        6.23
# 7         130812        6.10
# 8         253100       11.81
# 9         227147       10.60
# 10        206765        9.65
# 11        180909        8.44
# 12         82627        3.86

# %% [markdown]
# ## Quantos foram por cada ano e mês ?

# %%
emprestimos_por_ano_e_mes = emprestimos_data.groupby(by=[emprestimos_data.data.dt.year,emprestimos_data.data.dt.month]).sum()
emprestimos_por_ano_e_mes.index.names = ['ano','mes']
emprestimos_por_ano_e_mes
# Out:
#           quantidade
# ano  mes
# 2010 1          5408
#      2         12097
#      3         23417
#      4         19509
#      5         19315
# ...              ...
# 2020 1          3722
#      2         11083
#      3         11821
#      5             8
#      6             2
#
# [119 rows x 1 columns]

# %% [markdown]
# ### INCONSISTÊNCIA

# %%
emprestimos_por_ano_e_mes.reset_index().pivot(index='mes',columns='ano')
# Out:
#     quantidade                                                                 \
# ano       2010     2011     2012     2013     2014     2015     2016     2017
# mes
# 1       5408.0   1871.0   8058.0   8508.0  16887.0   6981.0      NaN   5288.0
# 2      12097.0  15646.0  23292.0  28310.0  27828.0  27524.0      NaN  20739.0
# 3      23417.0  24549.0  32072.0  27624.0  21956.0  30383.0      NaN  29101.0
# 4      19509.0  22644.0  27067.0  29871.0  20713.0  25356.0      NaN  21516.0
# 5      19315.0  24592.0  25879.0  25662.0  18521.0  23288.0      NaN  23989.0
# 6      15634.0  19335.0  16341.0  15259.0   7487.0  13491.0      NaN  18342.0
# 7       8196.0   9458.0   6926.0  16985.0  19979.0  14672.0  15076.0  15262.0
# 8      22817.0  27906.0  25408.0  26611.0  26143.0  20759.0  27776.0  28975.0
# 9      22706.0  26556.0  24240.0  26535.0  26715.0  16933.0  24700.0  22507.0
# 10     19176.0  22360.0  25167.0  23326.0  23677.0  19404.0  19105.0  20352.0
# ...

# %%
dados_2016_1.head()
# Out:
#    id_emprestimo codigo_barras                 data_renovacao  \
# 0        2351371    2011010806  2017/01/13 07:22:40.736000000
# 1        2351372       L078593  2017/01/31 07:31:36.960000000
# 2        2351373    2010040100  2017/01/31 07:31:36.902000000
# 3        2351374    2013105705  2017/01/31 07:31:36.843000000
# 4        2351375       L057436  2017/01/31 07:30:36.293000000
#
#                  data_emprestimo                 data_devolucao  \
# 0  2017/01/02 08:01:14.113000000  2017/01/30 07:05:05.000000000
# 1  2017/01/02 08:29:46.657000000  2017/02/21 13:16:48.000000000
# 2  2017/01/02 08:29:46.722000000  2017/02/21 13:16:33.000000000
# 3  2017/01/02 08:29:46.794000000  2017/02/21 13:15:46.000000000
# 4  2017/01/02 08:38:40.009000000  2017/02/21 13:16:29.000000000
#
#    matricula_ou_siape                    nome_usuario    tipo_vinculo_usuario
# 0        2.014036e+09              RENATA GOMES LOPES      ALUNO DE GRADUAÇÃO
# ...

# %%
dados_2017_1.head()
# Out:
#    id_emprestimo codigo_barras                 data_renovacao  \
# 0        2351371    2011010806  2017/01/13 07:22:40.736000000
# 1        2351372       L078593  2017/01/31 07:31:36.960000000
# 2        2351373    2010040100  2017/01/31 07:31:36.902000000
# 3        2351374    2013105705  2017/01/31 07:31:36.843000000
# 4        2351375       L057436  2017/01/31 07:30:36.293000000
#
#                  data_emprestimo                 data_devolucao  \
# 0  2017/01/02 08:01:14.113000000  2017/01/30 07:05:05.000000000
# 1  2017/01/02 08:29:46.657000000  2017/02/21 13:16:48.000000000
# 2  2017/01/02 08:29:46.722000000  2017/02/21 13:16:33.000000000
# 3  2017/01/02 08:29:46.794000000  2017/02/21 13:15:46.000000000
# 4  2017/01/02 08:38:40.009000000  2017/02/21 13:16:29.000000000
#
#    matricula_ou_siape                    nome_usuario    tipo_vinculo_usuario
# 0        2.014036e+09              RENATA GOMES LOPES      ALUNO DE GRADUAÇÃO
# ...

# %% [markdown]
# ## Qual é a quantidade de empréstimos por hora ao longo do dia ?

# %%
emprestimos_data.data
# Out:
# 0         2010-12-06 00:00:00.000
# 1         2010-12-15 00:00:00.000
# 2         2010-11-24 00:00:00.000
# 3         2010-08-09 16:03:57.373
# 4         2015-06-10 18:51:56.994
#                     ...
# 2139184   2013-03-01 20:26:43.853
# 2139185   2013-03-01 20:26:43.806
# 2139186   2013-03-01 20:24:56.349
# 2139187   2013-03-01 20:23:26.277
# 2139188   2020-06-09 11:54:02.852
# Name: data, Length: 2139189, dtype: datetime64[ns]

# %%
emprestimos_por_hora = emprestimos_data.groupby(by=emprestimos_data.data.dt.hour).sum()
emprestimos_por_hora.index.names = ['horas']
emprestimos_por_hora['percentual'] = round((emprestimos_por_hora.quantidade / emprestimos_por_hora.quantidade.sum()) * 100, 3)
emprestimos_por_hora
# Out:
#        quantidade  percentual
# horas
# 0              61       0.003
# 6              18       0.001
# 7           20400       0.952
# 8          107199       5.003
# 9          135740       6.335
# 10         189366       8.837
# 11         179488       8.376
# 12         147561       6.886
# 13         128208       5.983
# 14         154196       7.196
# 15         169727       7.921
# 16         214578      10.014
# 17         186947       8.724
# 18         186294       8.694
# 19         112562       5.253
# 20         145740       6.801
# 21          64227       2.997
# 22            440       0.021
# 23             54       0.003

# %% [markdown]
# # Dia 4 - Continuando a explorar os dados

# %%
import pandas as pd

# %%
emprestimos_completo
# Out:
#          id_emprestimo codigo_barras                 data_renovacao  \
# 0               709684       L095049                            NaN
# 1               709685       L167050                            NaN
# 2               709686    2006017618  2010/01/26 08:07:01.738000000
# 3               709687       L184117  2010/01/18 11:07:46.470000000
# 4               709688    2007027500  2010/01/19 15:59:26.464000000
# ...                ...           ...                            ...
# 2142801        2989086    2008047044                            NaN
# 2142802        2989087    2008047047                            NaN
# 2142803        2989088    2010052905                            NaN
# 2142804        2989089    2010048023                            NaN
# 2142805        2989090    2013106838                            NaN
#
#                        data_emprestimo                 data_devolucao  \
# 0        2010/01/04 07:44:10.721000000  2010/01/05 16:26:12.662000000
# ...

# %%
emprestimos_completo['data_emprestimo'] = pd.to_datetime(emprestimos_completo['data_emprestimo'])

# %% [markdown]
# ## Funções

# %%
def tabela_frequencia(variavel):
  '''
  Esta função irá gerar uma tabela de frequência com percentuais de acordo 
  com a variável passada. 

  variavel = variável categórica escolhida de dentro do conjunto de dados 
  emprestimos_completo
  '''

  dataframe = pd.DataFrame(emprestimos_completo[variavel].value_counts())                      
  dataframe.columns = ['quantidade']
  dataframe['percentual'] = round((dataframe.quantidade / dataframe.quantidade.sum())*100,4)

  return dataframe

# %%
def tabela_frequencia_por_ano(variavel):
  '''
  Esta função irá gerar uma tabela de frequência com percentuais de acordo 
  com a variável passada. 

  variavel = variável categórica escolhida de dentro do conjunto de dados 
  emprestimos_completo
  '''

  dataframe = emprestimos_completo.loc[:,['data_emprestimo', variavel]]
  dataframe['data_emprestimo'] = dataframe['data_emprestimo'].dt.year
  dataframe = pd.DataFrame(dataframe.value_counts().groupby(by=['data_emprestimo',variavel]).sum(),columns=['quantidade'])
  dataframe.index.names = ['ano',variavel]
  dataframe = dataframe.reset_index().pivot(index=variavel,columns='ano')

  return dataframe

# %% [markdown]
# ## Quantos foram por tipo de vinculo do usuario ?

# %%
tabela_frequencia('tipo_vinculo_usuario')
# Out:
#                                  quantidade  percentual
# ALUNO DE GRADUAÇÃO                  1680815     78.4399
# ALUNO DE PÓS-GRADUAÇÃO               302621     14.1227
# DOCENTE                               74212      3.4633
# SERVIDOR TÉCNICO-ADMINISTRATIVO       32546      1.5188
# ALUNO MÉDIO/TÉCNICO                   27541      1.2853
# DOCENTE EXTERNO                       22520      1.0510
# USUÁRIO EXTERNO                        2545      0.1188
# OUTROS                                    6      0.0003

# %% [markdown]
# ## Quantos foram por tipo de vinculo por ano ?

# %%
tabela_frequencia_por_ano('tipo_vinculo_usuario')
# Out:
#                                 quantidade                                \
# ano                                   2010      2011      2012      2013
# tipo_vinculo_usuario
# ALUNO DE GRADUAÇÃO                156929.0  189140.0  203694.0  208429.0
# ALUNO DE PÓS-GRADUAÇÃO             26866.0   28113.0   31186.0   34832.0
# ALUNO MÉDIO/TÉCNICO                 1030.0    1300.0    2909.0    3243.0
# DOCENTE                             6975.0    7078.0    8133.0    8436.0
# DOCENTE EXTERNO                      509.0     425.0     644.0     698.0
# OUTROS                                 6.0       NaN       NaN       NaN
# SERVIDOR TÉCNICO-ADMINISTRATIVO     3561.0    3329.0    3517.0    3746.0
# USUÁRIO EXTERNO                      271.0     163.0     177.0     215.0
#
#                                                                         \
# ano                                  2014      2015     2016      2017
# tipo_vinculo_usuario
# ...

# %% [markdown]
# ## Quantos foram por coleção ?

# %%
tabela_frequencia('colecao')
# Out:
#                                        quantidade  percentual
# Acervo Circulante                         1940746     98.5214
# Acervo de Desbaste                          10383      0.5271
# Multimeios                                   7644      0.3880
# Monografias                                  3930      0.1995
# Dissertações                                 2319      0.1177
# Obras de Referência                          1878      0.0953
# Publicações de Autores do RN                  842      0.0427
# Publicações da UFRN                           740      0.0376
# Teses                                         698      0.0354
# Folhetos                                      267      0.0136
# Trabalho Acadêmico                            111      0.0056
# Necessidades Educacionais Específicas         108      0.0055
# Eventos                                       100      0.0051
# Coleção Mossoroense                            44      0.0022
# ...

# %% [markdown]
# ## Quantos foram por coleção por ano ?

# %%
tabela_frequencia_por_ano('colecao')
# Out:
#                                       quantidade                      \
# ano                                         2010      2011      2012
# colecao
# Acervo Circulante                       159087.0  193782.0  218807.0
# Acervo de Desbaste                        1898.0    1578.0    1017.0
# Coleção Mossoroense                         16.0       5.0       6.0
# Coleção Zila Mamede                          2.0       4.0       6.0
# Dissertações                               405.0     370.0     354.0
# Eventos                                     23.0      12.0      10.0
# Folhetos                                    40.0      35.0      39.0
# Literatura de Cordel                         1.0       1.0       NaN
# Monografias                                584.0     612.0     504.0
# Multimeios                                 779.0    1083.0    1204.0
# Necessidades Educacionais Específicas        NaN       2.0      14.0
# ...

# %% [markdown]
# ## Quantos foram por biblioteca ?

# %%
tabela_frequencia('biblioteca')
# Out:
#                                                     quantidade  percentual
# Biblioteca Central Zila Mamede                         1359077     68.9932
# Biblioteca Setorial do Centro Ciências da Saúde...      113332      5.7533
# Biblioteca Setorial da Faculdade de Ciências da...       72324      3.6715
# Biblioteca Setorial Prof. Alberto Moreira Campo...       62496      3.1726
# Biblioteca Setorial Profª. Maria Lúcia da Costa...       57263      2.9069
# Biblioteca Setorial Bertha Cruz Enders - ­Escol...       44419      2.2549
# Biblioteca Setorial do Centro de Ciências Human...       38572      1.9581
# Biblioteca Setorial Dr. Paulo Bezerra - EMCM/RN...       32472      1.6484
# Biblioteca Setorial Profª. Maria José Mamede Ga...       27547      1.3984
# Biblioteca Setorial Prof. Francisco Gurgel De A...       25574      1.2983
# Biblioteca Setorial Prof. Rodolfo Helinski - Es...       24729      1.2554
# ...

# %% [markdown]
# ## Quantos foram por biblioteca por ano ?

# %%
tabela_frequencia_por_ano('biblioteca')
# Out:
#                                                    quantidade            \
# ano                                                      2010      2011
# biblioteca
# Biblioteca Central Zila Mamede                       123309.0  146504.0
# Biblioteca Setorial Bertha Cruz Enders - ­Escol...     5386.0    5781.0
# Biblioteca Setorial Dr. Paulo Bezerra - EMCM/RN...      107.0     109.0
# Biblioteca Setorial Moacyr de Góes - CE                  89.0     160.0
# Biblioteca Setorial Pe. Jaime Diniz - Escola de...     1068.0    2073.0
# Biblioteca Setorial Prof. Alberto Moreira Campo...     5940.0    5709.0
# Biblioteca Setorial Prof. Dr. Marcelo Bezerra d...      637.0     741.0
# Biblioteca Setorial Prof. Francisco Gurgel De A...     3065.0    2907.0
# Biblioteca Setorial Prof. Horácio Nicolas Solim...      685.0     659.0
# Biblioteca Setorial Prof. Leopoldo Nelson - ­Ce...       55.0      87.0
# Biblioteca Setorial Prof. Rodolfo Helinski - Es...      386.0     257.0
# ...

# %% [markdown]
# ## Quantos foram pela CDU geral?

# %%
tabela_frequencia('CDU_geral')
# Out:
#                                  quantidade  percentual
# Ciências aplicadas                  1375520     64.1925
# Ciências sociais                     342693     15.9927
# Geografia. Biografia. História.      180914      8.4429
# Matemática e ciências naturais        61118      2.8522
# Generalidades                         56443      2.6341
# Religião                              56151      2.6204
# Filosofia e psicologia                54596      2.5479
# Belas artes                            7892      0.3683
# Linguagem                              7479      0.3490

# %% [markdown]
# ## Quantos foram pela CDU geral por ano?

# %%
tabela_frequencia_por_ano('CDU_geral')
# Out:
#                                 quantidade                                  \
# ano                                   2010    2011    2012    2013    2014
# CDU_geral
# Belas artes                             38      52      55     142      83
# Ciências aplicadas                  162476  196803  201174  188020  152327
# Ciências sociais                       506     773   20728   46893   54169
# Filosofia e psicologia                  38      50     100     115    4438
# Generalidades                           43      52      89      96    4445
# Geografia. Biografia. História.      32916   31643   27934   24114   15711
# Linguagem                               60      56      54      53      33
# Matemática e ciências naturais          43      79      65      66      91
# Religião                                27      40      61     100    4428
#
#
# ano                                2015   2016    2017   2018   2019   2020
# CDU_geral
# ...

# %% [markdown]
# # Dia 5 - Analisando empréstimos com boxplot

# %%
import pandas as pd

# %%
emprestimos_completo
# Out:
#          id_emprestimo codigo_barras                 data_renovacao  \
# 0               709684       L095049                            NaN
# 1               709685       L167050                            NaN
# 2               709686    2006017618  2010/01/26 08:07:01.738000000
# 3               709687       L184117  2010/01/18 11:07:46.470000000
# 4               709688    2007027500  2010/01/19 15:59:26.464000000
# ...                ...           ...                            ...
# 2142801        2989086    2008047044                            NaN
# 2142802        2989087    2008047047                            NaN
# 2142803        2989088    2010052905                            NaN
# 2142804        2989089    2010048023                            NaN
# 2142805        2989090    2013106838                            NaN
#
#                 data_emprestimo                 data_devolucao  \
# 0       2010-01-04 07:44:10.721  2010/01/05 16:26:12.662000000
# ...

# %%
zila_mamede_emprestimo_aluno_graduacao =  emprestimos_completo.query('biblioteca == "Biblioteca Central Zila Mamede" and data_emprestimo >= "2017-01-01" and data_emprestimo < "2020-01-01"  and tipo_vinculo_usuario == "ALUNO DE GRADUAÇÃO"')
zila_mamede_tipo_usuario_emprestimo = zila_mamede_emprestimo_aluno_graduacao.loc[:,['data_emprestimo']]
zila_mamede_tipo_usuario_emprestimo['ano'] = zila_mamede_tipo_usuario_emprestimo.data_emprestimo.dt.year
zila_mamede_tipo_usuario_emprestimo['mes'] = zila_mamede_tipo_usuario_emprestimo.data_emprestimo.dt.month
zila_mamede_tipo_usuario_emprestimo = zila_mamede_tipo_usuario_emprestimo.drop('data_emprestimo',axis=1)
zila_mamede_tipo_usuario_emprestimo = zila_mamede_tipo_usuario_emprestimo.value_counts().reset_index()
zila_mamede_tipo_usuario_emprestimo.columns = ['ano','mes','quantidade']
zila_mamede_tipo_usuario_emprestimo = zila_mamede_tipo_usuario_emprestimo.drop('mes',axis=1)
zila_mamede_tipo_usuario_emprestimo.head()
# Out:
#     ano  quantidade
# 0  2017       14437
# 1  2017       14190
# 2  2018       13422
# 3  2018       11923
# 4  2017       11498

# %%
zila_mamede_tipo_usuario_emprestimo.pivot(columns='ano',values='quantidade').describe()
# Out:
# ano            2017          2018          2019
# count     12.000000     12.000000     12.000000
# mean    9301.833333   8150.500000   7041.166667
# std     3849.061109   3478.493234   3101.358905
# min     2043.000000   2179.000000   1417.000000
# 25%     8279.750000   6751.500000   5604.750000
# 50%     9965.500000   9051.000000   7666.500000
# 75%    11189.750000   9964.250000   8914.500000
# max    14437.000000  13422.000000  11485.000000

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
def gera_box_plot(dataset,x,y,titulo):
  '''
  Esta função irá gerar um gráfico de boxplot.

  Dataset = conjunto de dados do gráfico
  x = valor do eixo x do gráfico
  y = valor do eixo y do gráfico
  título = título do gráfico
  '''

  sns.set_theme(style="darkgrid", palette='coolwarm',font_scale=1.3)                    #Definir a cor do fundo, paleta de cores e fonte dos eixos
  plt.figure(figsize=(16,10))                                                           #Dimensionar o tamanho

  ax = sns.boxplot(y= y, x= x, data= dataset)                                           #Plotar o gráfico

  plt.ylim(0,max(dataset[y])*1.1)                                                       #Definir o limite do eixo y
  plt.xlabel(None)                                                                      #Excluir título do eixo x
  plt.ylabel(None)                                                                      #Excluir título do eixo x

  plt.title(titulo,loc='left',size=20)                                                  #Gerar o título

# %%
zila_mamede_tipo_usuario_emprestimo
# Out:
#      ano  quantidade
# 0   2017       14437
# 1   2017       14190
# 2   2018       13422
# 3   2018       11923
# 4   2017       11498
# 5   2019       11485
# 6   2017       11087
# 7   2018       10916
# 8   2017       10699
# 9   2017       10591
# 10  2019        9803
# 11  2019        9720
# 12  2018        9647
# 13  2017        9340
# 14  2018        9265
# 15  2018        9081
# 16  2018        9021
# 17  2017        8708
# 18  2019        8646
# 19  2019        8400
# 20  2017        8312
# 21  2017        8183
# 22  2019        8005
# 23  2018        7543
# 24  2018        7505
# 25  2019        7328
# 26  2019        7131
# 27  2019        5763
# 28  2019        5130
# 29  2018        4491
# 30  2018        2813
# 31  2017        2534
# 32  2018        2179
# 33  2017        2043
# 34  2019        1666
# 35  2019        1417

# %%
gera_box_plot(zila_mamede_tipo_usuario_emprestimo,'ano','quantidade','Distribuição da quantidade de empréstimos por mês' + '\n' + 'dos alunos de graduação da biblioteca Zila Mamede')

# %%
zila_mamede_tipo_usuario_emprestimo.pivot(columns='ano',values='quantidade').describe()
# Out:
# ano            2017          2018          2019
# count     12.000000     12.000000     12.000000
# mean    9301.833333   8150.500000   7041.166667
# std     3849.061109   3478.493234   3101.358905
# min     2043.000000   2179.000000   1417.000000
# 25%     8279.750000   6751.500000   5604.750000
# 50%     9965.500000   9051.000000   7666.500000
# 75%    11189.750000   9964.250000   8914.500000
# max    14437.000000  13422.000000  11485.000000

# %%
zila_mamede_emprestimo_aluno_graduacao.CDU_geral.value_counts()
# Out:
# Ciências aplicadas                 155740
# Ciências sociais                    67077
# Matemática e ciências naturais      21501
# Generalidades                       14971
# Religião                            14733
# Filosofia e psicologia              14080
# Geografia. Biografia. História.      2080
# Belas artes                          1987
# Linguagem                            1753
# Name: CDU_geral, dtype: int64

# %%
def gera_tabela_emprestimos_por_CDU(CDU):
  '''
  Esta função irá gerar a tabela da quantidade de empréstimos por alunos de 
  graduação, nos anos de 2017,2018 e 2019 (definida pela variável 
  zila_mamede_emprestimo_aluno_graduacao) filtrada pela CDU escolhida.

  CDU = Classificação geral da CDU definida na tabela
  '''

  
  zila_mamede_emprestimo_aluno_graduacao_CDU =  zila_mamede_emprestimo_aluno_graduacao[zila_mamede_emprestimo_aluno_graduacao['CDU_geral']==CDU]
  zila_mamede_emprestimo_aluno_graduacao_CDU = zila_mamede_emprestimo_aluno_graduacao_CDU.loc[:,['data_emprestimo']]
  zila_mamede_emprestimo_aluno_graduacao_CDU['ano'] = zila_mamede_emprestimo_aluno_graduacao_CDU.data_emprestimo.dt.year
  zila_mamede_emprestimo_aluno_graduacao_CDU['mes'] = zila_mamede_emprestimo_aluno_graduacao_CDU.data_emprestimo.dt.month
  zila_mamede_emprestimo_aluno_graduacao_CDU = zila_mamede_emprestimo_aluno_graduacao_CDU.drop('data_emprestimo',axis=1)
  zila_mamede_emprestimo_aluno_graduacao_CDU = zila_mamede_emprestimo_aluno_graduacao_CDU.value_counts().reset_index()
  zila_mamede_emprestimo_aluno_graduacao_CDU.columns = ['ano','mes','quantidade']
  zila_mamede_emprestimo_aluno_graduacao_CDU = zila_mamede_emprestimo_aluno_graduacao_CDU.drop('mes',axis=1)
  
  return zila_mamede_emprestimo_aluno_graduacao_CDU

# %%
gera_tabela_emprestimos_por_CDU('Ciências aplicadas')
# Out:
#      ano  quantidade
# 0   2017        8335
# 1   2017        8043
# 2   2018        7227
# 3   2018        6612
# 4   2017        6340
# 5   2017        6277
# 6   2019        6173
# 7   2017        6012
# 8   2018        5821
# 9   2017        5800
# 10  2019        5227
# 11  2019        5128
# 12  2018        4987
# 13  2017        4946
# 14  2018        4828
# 15  2018        4809
# 16  2018        4738
# 17  2017        4731
# 18  2019        4371
# 19  2019        4331
# 20  2017        4310
# 21  2017        4195
# 22  2019        4086
# 23  2018        3838
# 24  2018        3816
# 25  2019        3680
# 26  2019        3534
# 27  2019        2923
# 28  2019        2489
# 29  2018        2126
# 30  2018        1333
# 31  2017        1236
# 32  2018        1029
# 33  2017         996
# 34  2019         753
# 35  2019         660

# %%
emprestimos_ciencias_aplicadas = gera_tabela_emprestimos_por_CDU('Ciências aplicadas')

# %%
emprestimos_ciencias_aplicadas.pivot(columns='ano',values='quantidade').describe()
# Out:
# ano           2017         2018         2019
# count    12.000000    12.000000    12.000000
# mean   5101.750000  4263.666667  3612.916667
# std    2271.311681  1956.073448  1690.014871
# min     996.000000  1029.000000   660.000000
# 25%    4281.250000  3393.500000  2814.500000
# 50%    5373.000000  4773.500000  3883.000000
# 75%    6292.750000  5195.500000  4560.250000
# max    8335.000000  7227.000000  6173.000000

# %%
gera_box_plot(emprestimos_ciencias_aplicadas,'ano','quantidade','Distribuição da quantidade de empréstimos em ciências aplicadas por mês' + '\n' + 'dos alunos de graduação da biblioteca Zila Mamede')

# %%
emprestimos_ciencias_sociais = gera_tabela_emprestimos_por_CDU('Ciências sociais')

# %%
emprestimos_ciencias_sociais.pivot(columns='ano',values='quantidade').describe()
# Out:
# ano           2017         2018         2019
# count    12.000000    12.000000    12.000000
# mean   2164.750000  1846.916667  1578.083333
# std     840.768493   768.395667   698.603342
# min     473.000000   501.000000   287.000000
# 25%    2060.750000  1498.500000  1253.500000
# 50%    2297.000000  2051.500000  1774.500000
# 75%    2645.750000  2249.250000  2019.000000
# max    3216.000000  3055.000000  2573.000000

# %%
gera_box_plot(emprestimos_ciencias_sociais,'ano','quantidade','Distribuição da quantidade de empréstimos em ciências sociais por mês' + '\n' + 'dos alunos de graduação da biblioteca Zila Mamede')

# %%
emprestimos_matematica_ciencias_naturais = gera_tabela_emprestimos_por_CDU('Matemática e ciências naturais')

# %%
emprestimos_matematica_ciencias_naturais.pivot(columns='ano',values='quantidade').describe()
# Out:
# ano          2017        2018        2019
# count   12.000000   12.000000   12.000000
# mean   591.083333  657.250000  543.416667
# std    214.672037  226.070434  221.932200
# min    148.000000  259.000000  144.000000
# 25%    541.750000  584.500000  425.500000
# 50%    611.500000  689.500000  603.000000
# 75%    723.750000  840.750000  684.750000
# max    917.000000  925.000000  858.000000

# %%
gera_box_plot(emprestimos_matematica_ciencias_naturais,'ano','quantidade','Distribuição da quantidade de empréstimos em matemática e ciências naturais por mês' + '\n' + 'dos alunos de graduação da biblioteca Zila Mamede')

# %%
emprestimos_generalidades = gera_tabela_emprestimos_por_CDU('Generalidades')

# %%
emprestimos_generalidades.pivot(columns='ano',values='quantidade').describe()
# Out:
# ano          2017        2018        2019
# count   12.000000   12.000000   12.000000
# mean   491.583333  413.250000  342.750000
# std    183.206520  164.554012  135.213047
# min    136.000000  124.000000   77.000000
# 25%    466.500000  329.000000  308.750000
# 50%    528.500000  461.000000  378.000000
# 75%    579.500000  503.500000  440.500000
# max    715.000000  643.000000  475.000000

# %%
gera_box_plot(emprestimos_generalidades,'ano','quantidade','Distribuição da quantidade de empréstimos em generalidades por mês' + '\n' + 'dos alunos de graduação da biblioteca Zila Mamede')

# %%
emprestimos_religião = gera_tabela_emprestimos_por_CDU('Religião')

# %%
emprestimos_religião.pivot(columns='ano',values='quantidade').describe()
# Out:
# ano          2017        2018        2019
# count   12.000000   12.000000   12.000000
# mean   483.750000  410.750000  333.250000
# std    192.545213  165.875706  143.897138
# min    131.000000  130.000000   71.000000
# 25%    442.750000  328.000000  258.750000
# 50%    521.500000  459.000000  385.000000
# 75%    565.000000  513.750000  417.500000
# max    768.000000  654.000000  531.000000

# %%
gera_box_plot(emprestimos_religião,'ano','quantidade','Distribuição da quantidade de empréstimos em religião por mês' + '\n' + 'dos alunos de graduação da biblioteca Zila Mamede')

# %%
emprestimos_filosofia_psicologia = gera_tabela_emprestimos_por_CDU('Filosofia e psicologia')

# %%
emprestimos_filosofia_psicologia.pivot(columns='ano',values='quantidade').describe()
# Out:
# ano          2017        2018        2019
# count   12.000000   12.000000   12.000000
# mean   466.000000  384.666667  322.666667
# std    180.565274  159.819406  126.621364
# min    137.000000  110.000000   84.000000
# 25%    414.750000  311.000000  274.250000
# 50%    495.000000  416.500000  363.500000
# 75%    552.000000  500.250000  404.750000
# max    718.000000  599.000000  483.000000

# %%
gera_box_plot(emprestimos_filosofia_psicologia,'ano','quantidade','Distribuição da quantidade de empréstimos em filosofia e psicologia por mês' + '\n' + 'dos alunos de graduação da biblioteca Zila Mamede')

# %%
emprestimos_geografia_biografia_historia = gera_tabela_emprestimos_por_CDU('Geografia. Biografia. História.')

# %%
emprestimos_geografia_biografia_historia.pivot(columns='ano',values='quantidade').describe()
# Out:
# ano        2017        2018        2019
# count  8.000000   12.000000   12.000000
# mean   1.500000   62.333333  110.000000
# std    0.755929   33.866941   39.221979
# min    1.000000   10.000000   34.000000
# 25%    1.000000   41.500000   98.500000
# 50%    1.000000   56.000000  117.500000
# 75%    2.000000   94.500000  135.750000
# max    3.000000  110.000000  152.000000

# %%
gera_box_plot(emprestimos_geografia_biografia_historia,'ano','quantidade','Distribuição da quantidade de empréstimos em geografia,biografia e história por mês' + '\n' + 'dos alunos de graduação da biblioteca Zila Mamede')

# %%
emprestimos_belas_artes = gera_tabela_emprestimos_por_CDU('Belas artes')

# %%
emprestimos_belas_artes.pivot(columns='ano',values='quantidade').describe()
# Out:
# ano        2017        2018        2019
# count  8.000000   12.000000   12.000000
# mean   1.125000   57.583333  107.250000
# std    0.353553   29.137475   38.203106
# min    1.000000    9.000000   28.000000
# 25%    1.000000   40.750000   97.000000
# 50%    1.000000   53.500000  122.000000
# 75%    1.000000   81.250000  129.750000
# max    2.000000  115.000000  152.000000

# %%
gera_box_plot(emprestimos_belas_artes,'ano','quantidade','Distribuição da quantidade de empréstimos em belas artes por mês' + '\n' + 'dos alunos de graduação da biblioteca Zila Mamede')

# %%
emprestimos_linguagem = gera_tabela_emprestimos_por_CDU('Linguagem')

# %%
emprestimos_linguagem.pivot(columns='ano',values='quantidade').describe()
# Out:
# ano        2017       2018        2019
# count  8.000000  12.000000   12.000000
# mean   1.750000  54.083333   90.833333
# std    1.035098  30.251847   31.452224
# min    1.000000   3.000000   27.000000
# 25%    1.000000  38.500000   80.500000
# 50%    1.500000  52.000000  100.500000
# 75%    2.000000  79.500000  112.750000
# max    4.000000  95.000000  120.000000

# %%
gera_box_plot(emprestimos_linguagem,'ano','quantidade','Distribuição da quantidade de empréstimos em linguagens por mês' + '\n' + 'dos alunos de graduação da biblioteca Zila Mamede')

# %% [markdown]
# #Dia 6 - Novos dados, novas análises

# %% [markdown]
# ## Arquivo excel

# %%
cadastro_usuarios_antes_2010 = pd.read_excel('https://github.com/FranciscoFoz/7_Days_of_Code_Alura-Python-Pandas/raw/main/Dia_6-Novos_dados_novas_analises/Datasets/matricula_alunos.xlsx',
                                        sheet_name='Até 2010',skiprows=1)
cadastro_usuarios_depois_2010 = pd.read_excel('https://github.com/FranciscoFoz/7_Days_of_Code_Alura-Python-Pandas/raw/main/Dia_6-Novos_dados_novas_analises/Datasets/matricula_alunos.xlsx',
                                        sheet_name='Após 2010',skiprows=1)

# %%
cadastro_usuarios_antes_2010
# Out:
#       Número da matrícula     Tipo de vinculo  \
# 0            1.900017e+08  ALUNO DE GRADUAÇÃO
# 1            1.990145e+08  ALUNO DE GRADUAÇÃO
# 2            1.997357e+08  ALUNO DE GRADUAÇÃO
# 3            1.998124e+08  ALUNO DE GRADUAÇÃO
# 4            1.998237e+08  ALUNO DE GRADUAÇÃO
# ...                   ...                 ...
# 7721         2.009075e+09  ALUNO DE GRADUAÇÃO
# 7722         2.009075e+09  ALUNO DE GRADUAÇÃO
# 7723         2.009075e+09  ALUNO DE GRADUAÇÃO
# 7724         2.009075e+09  ALUNO DE GRADUAÇÃO
# 7725         2.009075e+09  ALUNO DE GRADUAÇÃO
#
#                                       Curso
# 0                                MATEMÁTICA
# 1                       CIÊNCIAS BIOLÓGICAS
# 2                                MATEMÁTICA
# 3                                    LETRAS
# 4                                  ECOLOGIA
# ...                                     ...
# 7721                        BIBLIOTECONOMIA
# 7722  ANÁLISE E DESENVOLVIMENTO DE SISTEMAS
# ...

# %%
cadastro_usuarios_antes_2010.columns = ['matricula_ou_siape','tipo_vinculo_usuario','curso']

# %%
cadastro_usuarios_depois_2010
# Out:
#         Matricula      Tipo de vinculo                    Cursos
# 0     2.010000e+09  ALUNO DE GRADUAÇÃO                   DIREITO
# 1     2.010000e+09  ALUNO DE GRADUAÇÃO                 AGRONOMIA
# 2     2.010001e+09  ALUNO DE GRADUAÇÃO        ENGENHARIA QUÍMICA
# 3     2.010003e+09  ALUNO DE GRADUAÇÃO      ENGENHARIA AMBIENTAL
# 4     2.010003e+09  ALUNO DE GRADUAÇÃO                 GEOGRAFIA
# ...            ...                 ...                       ...
# 2269  2.015012e+10  ALUNO DE GRADUAÇÃO                    LETRAS
# 2270  2.015075e+09  ALUNO DE GRADUAÇÃO                     DANÇA
# 2271  2.016000e+10  ALUNO DE GRADUAÇÃO  ENGENHARIA DA COMPUTAÇÃO
# 2272  2.017009e+10  ALUNO DE GRADUAÇÃO           BIBLIOTECONOMIA
# 2273  2.018009e+10  ALUNO DE GRADUAÇÃO                     DANÇA
#
# [2274 rows x 3 columns]

# %%
cadastro_usuarios_depois_2010.columns= ['matricula_ou_siape','tipo_vinculo_usuario','curso']

# %%
cadastro_usuarios_excel = pd.concat([cadastro_usuarios_antes_2010,cadastro_usuarios_depois_2010],ignore_index=True)
cadastro_usuarios_excel.matricula_ou_siape = cadastro_usuarios_excel.matricula_ou_siape.astype('string')
cadastro_usuarios_excel
# Out:
#      matricula_ou_siape tipo_vinculo_usuario                     curso
# 0           190001688.0   ALUNO DE GRADUAÇÃO                MATEMÁTICA
# 1           199014489.0   ALUNO DE GRADUAÇÃO       CIÊNCIAS BIOLÓGICAS
# 2           199735674.0   ALUNO DE GRADUAÇÃO                MATEMÁTICA
# 3           199812431.0   ALUNO DE GRADUAÇÃO                    LETRAS
# 4           199823670.0   ALUNO DE GRADUAÇÃO                  ECOLOGIA
# ...                 ...                  ...                       ...
# 9995      20150116770.0   ALUNO DE GRADUAÇÃO                    LETRAS
# 9996       2015074523.0   ALUNO DE GRADUAÇÃO                     DANÇA
# 9997      20160002745.0   ALUNO DE GRADUAÇÃO  ENGENHARIA DA COMPUTAÇÃO
# 9998      20170086533.0   ALUNO DE GRADUAÇÃO           BIBLIOTECONOMIA
# 9999      20180090351.0   ALUNO DE GRADUAÇÃO                     DANÇA
#
# [10000 rows x 3 columns]

# %% [markdown]
# ## Arquivo JSON

# %%
cadastro_usuarios_json = pd.read_json('https://github.com/FranciscoFoz/7_Days_of_Code_Alura-Python-Pandas/raw/main/Dia_6-Novos_dados_novas_analises/Datasets/cadastro_alunos.json')
cadastro_usuarios_json
# Out:
#      tipo_curso                                          registros
# 0     GRADUACAO  [{"matricula_ou_siape": "2009029003.0", "tipo_...
# 1  POSGRADUACAO  [{"matricula_ou_siape": "2008112114.0", "tipo_...

# %%
cadastro_usuarios_graduacao = pd.read_json(cadastro_usuarios_json.registros[0])
cadastro_usuarios_pos_graduacao = pd.read_json(cadastro_usuarios_json.registros[1])

# %%
cadastro_usuarios_graduacao
# Out:
#        matricula_ou_siape tipo_vinculo_usuario                   curso
# 0              2009029003   ALUNO DE GRADUAÇÃO               FILOSOFIA
# 1               200617346   ALUNO DE GRADUAÇÃO                 DIREITO
# 2               200746502   ALUNO DE GRADUAÇÃO  ENGENHARIA DE PETRÓLEO
# 3               200504968   ALUNO DE GRADUAÇÃO           ADMINISTRAÇÃO
# 4               200615572   ALUNO DE GRADUAÇÃO   CIÊNCIA DA COMPUTAÇÃO
# ...                   ...                  ...                     ...
# 62797         20200012706   ALUNO DE GRADUAÇÃO         BIBLIOTECONOMIA
# 62798         20200039601   ALUNO DE GRADUAÇÃO    ENGENHARIA FLORESTAL
# 62799         20200132517   ALUNO DE GRADUAÇÃO               AGRONOMIA
# 62800         20200009344   ALUNO DE GRADUAÇÃO         BIBLIOTECONOMIA
# 62801         20200090284   ALUNO DE GRADUAÇÃO                 DIREITO
#
# [62802 rows x 3 columns]

# %%
cadastro_usuarios_pos_graduacao
# Out:
#        matricula_ou_siape    tipo_vinculo_usuario  \
# 0              2008112114  ALUNO DE PÓS-GRADUAÇÃO
# 1              2008106583  ALUNO DE PÓS-GRADUAÇÃO
# 2              2011101417  ALUNO DE PÓS-GRADUAÇÃO
# 3              2011113122  ALUNO DE PÓS-GRADUAÇÃO
# 4              2010110903  ALUNO DE PÓS-GRADUAÇÃO
# ...                   ...                     ...
# 19435         20201013501  ALUNO DE PÓS-GRADUAÇÃO
# 19436         20201014062  ALUNO DE PÓS-GRADUAÇÃO
# 19437         20201017690  ALUNO DE PÓS-GRADUAÇÃO
# 19438         20201014465  ALUNO DE PÓS-GRADUAÇÃO
# 19439         20201014993  ALUNO DE PÓS-GRADUAÇÃO
#
#                                         curso
# 0                      CIÊNCIAS ODONTOLÓGICAS
# 1                      ENGENHARIA DE SOFTWARE
# 2                     ARQUITETURA E URBANISMO
# 3                                   FILOSOFIA
# 4                               ARTES CÊNICAS
# ...                                       ...
# ...

# %%
cadastro_usuarios_json = pd.concat([cadastro_usuarios_graduacao,cadastro_usuarios_pos_graduacao],ignore_index=True)
cadastro_usuarios_json
# Out:
#        matricula_ou_siape    tipo_vinculo_usuario  \
# 0              2009029003      ALUNO DE GRADUAÇÃO
# 1               200617346      ALUNO DE GRADUAÇÃO
# 2               200746502      ALUNO DE GRADUAÇÃO
# 3               200504968      ALUNO DE GRADUAÇÃO
# 4               200615572      ALUNO DE GRADUAÇÃO
# ...                   ...                     ...
# 82237         20201013501  ALUNO DE PÓS-GRADUAÇÃO
# 82238         20201014062  ALUNO DE PÓS-GRADUAÇÃO
# 82239         20201017690  ALUNO DE PÓS-GRADUAÇÃO
# 82240         20201014465  ALUNO DE PÓS-GRADUAÇÃO
# 82241         20201014993  ALUNO DE PÓS-GRADUAÇÃO
#
#                                         curso
# 0                                   FILOSOFIA
# 1                                     DIREITO
# 2                      ENGENHARIA DE PETRÓLEO
# 3                               ADMINISTRAÇÃO
# 4                       CIÊNCIA DA COMPUTAÇÃO
# ...                                       ...
# ...

# %%
cadastro_usuarios_json.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 82242 entries, 0 to 82241
# Data columns (total 3 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   matricula_ou_siape    82242 non-null  int64
#  1   tipo_vinculo_usuario  82242 non-null  object
#  2   curso                 82242 non-null  object
# dtypes: int64(1), object(2)
# memory usage: 1.9+ MB

# %%
cadastro_usuarios_json.matricula_ou_siape = cadastro_usuarios_json.matricula_ou_siape.astype('float')
cadastro_usuarios_json.matricula_ou_siape = cadastro_usuarios_json.matricula_ou_siape.astype('string')

# %%
cadastro_usuarios_json
# Out:
#       matricula_ou_siape    tipo_vinculo_usuario  \
# 0           2009029003.0      ALUNO DE GRADUAÇÃO
# 1            200617346.0      ALUNO DE GRADUAÇÃO
# 2            200746502.0      ALUNO DE GRADUAÇÃO
# 3            200504968.0      ALUNO DE GRADUAÇÃO
# 4            200615572.0      ALUNO DE GRADUAÇÃO
# ...                  ...                     ...
# 82237      20201013501.0  ALUNO DE PÓS-GRADUAÇÃO
# 82238      20201014062.0  ALUNO DE PÓS-GRADUAÇÃO
# 82239      20201017690.0  ALUNO DE PÓS-GRADUAÇÃO
# 82240      20201014465.0  ALUNO DE PÓS-GRADUAÇÃO
# 82241      20201014993.0  ALUNO DE PÓS-GRADUAÇÃO
#
#                                         curso
# 0                                   FILOSOFIA
# 1                                     DIREITO
# 2                      ENGENHARIA DE PETRÓLEO
# 3                               ADMINISTRAÇÃO
# 4                       CIÊNCIA DA COMPUTAÇÃO
# ...                                       ...
# ...

# %%
cadastro_usuarios_cursos = pd.concat([cadastro_usuarios_excel,cadastro_usuarios_json],ignore_index=True)
cadastro_usuarios_cursos
# Out:
#       matricula_ou_siape    tipo_vinculo_usuario  \
# 0            190001688.0      ALUNO DE GRADUAÇÃO
# 1            199014489.0      ALUNO DE GRADUAÇÃO
# 2            199735674.0      ALUNO DE GRADUAÇÃO
# 3            199812431.0      ALUNO DE GRADUAÇÃO
# 4            199823670.0      ALUNO DE GRADUAÇÃO
# ...                  ...                     ...
# 92237      20201013501.0  ALUNO DE PÓS-GRADUAÇÃO
# 92238      20201014062.0  ALUNO DE PÓS-GRADUAÇÃO
# 92239      20201017690.0  ALUNO DE PÓS-GRADUAÇÃO
# 92240      20201014465.0  ALUNO DE PÓS-GRADUAÇÃO
# 92241      20201014993.0  ALUNO DE PÓS-GRADUAÇÃO
#
#                                         curso
# 0                                  MATEMÁTICA
# 1                         CIÊNCIAS BIOLÓGICAS
# 2                                  MATEMÁTICA
# 3                                      LETRAS
# 4                                    ECOLOGIA
# ...                                       ...
# ...

# %% [markdown]
# ## Quantidade de empréstimos por curso

# %%
matricula_data_de_emprestimo = emprestimos_completo.query("tipo_vinculo_usuario == ['ALUNO DE GRADUAÇÃO','ALUNO DE PÓS-GRADUAÇÃO']")
matricula_data_de_emprestimo = matricula_data_de_emprestimo.loc[:,['matricula_ou_siape','data_emprestimo']]
matricula_data_de_emprestimo = matricula_data_de_emprestimo.query('data_emprestimo > 2017')
matricula_data_de_emprestimo = matricula_data_de_emprestimo.reset_index(drop=True)

# %%
matricula_data_de_emprestimo
# Out:
#        matricula_ou_siape         data_emprestimo
# 0            2014035816.0 2017-01-02 08:01:14.113
# 1           20161011168.0 2017-01-02 08:29:46.657
# 2           20161011168.0 2017-01-02 08:29:46.722
# 3           20161011168.0 2017-01-02 08:29:46.794
# 4           20161010760.0 2017-01-02 08:38:40.009
# ...                   ...                     ...
# 577947      20191017055.0 2020-03-19 14:41:57.754
# 577948      20191017055.0 2020-03-19 14:42:56.670
# 577949      20191017055.0 2020-03-19 14:43:40.666
# 577950      20201014993.0 2020-06-09 11:54:02.669
# 577951      20201014993.0 2020-06-09 11:54:02.852
#
# [577952 rows x 2 columns]

# %%
matricula_data_de_emprestimo
# Out:
#        matricula_ou_siape         data_emprestimo
# 0            2014035816.0 2017-01-02 08:01:14.113
# 1           20161011168.0 2017-01-02 08:29:46.657
# 2           20161011168.0 2017-01-02 08:29:46.722
# 3           20161011168.0 2017-01-02 08:29:46.794
# 4           20161010760.0 2017-01-02 08:38:40.009
# ...                   ...                     ...
# 577947      20191017055.0 2020-03-19 14:41:57.754
# 577948      20191017055.0 2020-03-19 14:42:56.670
# 577949      20191017055.0 2020-03-19 14:43:40.666
# 577950      20201014993.0 2020-06-09 11:54:02.669
# 577951      20201014993.0 2020-06-09 11:54:02.852
#
# [577952 rows x 2 columns]

# %%
matricula_data_de_emprestimo.isna().sum()
# Out:
# matricula_ou_siape    11
# data_emprestimo        0
# dtype: int64

# %%
matricula_data_de_emprestimo = matricula_data_de_emprestimo.dropna()

# %%
cadastro_usuarios_cursos
# Out:
#       matricula_ou_siape    tipo_vinculo_usuario  \
# 0            190001688.0      ALUNO DE GRADUAÇÃO
# 1            199014489.0      ALUNO DE GRADUAÇÃO
# 2            199735674.0      ALUNO DE GRADUAÇÃO
# 3            199812431.0      ALUNO DE GRADUAÇÃO
# 4            199823670.0      ALUNO DE GRADUAÇÃO
# ...                  ...                     ...
# 92237      20201013501.0  ALUNO DE PÓS-GRADUAÇÃO
# 92238      20201014062.0  ALUNO DE PÓS-GRADUAÇÃO
# 92239      20201017690.0  ALUNO DE PÓS-GRADUAÇÃO
# 92240      20201014465.0  ALUNO DE PÓS-GRADUAÇÃO
# 92241      20201014993.0  ALUNO DE PÓS-GRADUAÇÃO
#
#                                         curso
# 0                                  MATEMÁTICA
# 1                         CIÊNCIAS BIOLÓGICAS
# 2                                  MATEMÁTICA
# 3                                      LETRAS
# 4                                    ECOLOGIA
# ...                                       ...
# ...

# %%
emprestimos_cursos = matricula_data_de_emprestimo.merge(cadastro_usuarios_cursos)
emprestimos_cursos
# Out:
#        matricula_ou_siape         data_emprestimo    tipo_vinculo_usuario  \
# 0            2014035816.0 2017-01-02 08:01:14.113      ALUNO DE GRADUAÇÃO
# 1            2014035816.0 2017-02-08 13:32:13.820      ALUNO DE GRADUAÇÃO
# 2            2014035816.0 2017-02-17 11:53:03.346      ALUNO DE GRADUAÇÃO
# 3            2014035816.0 2017-02-24 16:44:51.766      ALUNO DE GRADUAÇÃO
# 4            2014035816.0 2017-03-17 14:49:18.969      ALUNO DE GRADUAÇÃO
# ...                   ...                     ...                     ...
# 577906      20201017690.0 2020-03-17 18:00:16.034  ALUNO DE PÓS-GRADUAÇÃO
# 577907      20201014465.0 2020-03-17 18:06:06.974  ALUNO DE PÓS-GRADUAÇÃO
# 577908      20200090284.0 2020-03-17 20:23:54.966      ALUNO DE GRADUAÇÃO
# 577909      20201014993.0 2020-06-09 11:54:02.669  ALUNO DE PÓS-GRADUAÇÃO
# 577910      20201014993.0 2020-06-09 11:54:02.852  ALUNO DE PÓS-GRADUAÇÃO
#
#                     curso
# 0        ENGENHARIA CIVIL
# ...

# %%
emprestimos_cursos.data_emprestimo = emprestimos_cursos.data_emprestimo.dt.year

# %%
emprestimos_tipo_usuario_e_curso = emprestimos_cursos.iloc[:,[1,2,3]].value_counts().reset_index()
emprestimos_tipo_usuario_e_curso.columns = ['ANO','TIPO_VINCULO_USUARIO','CURSO','QUANTIDADE_EMPRESTIMOS']
emprestimos_tipo_usuario_e_curso
# Out:
#       ANO TIPO_VINCULO_USUARIO                    CURSO  \
# 0    2017   ALUNO DE GRADUAÇÃO       COMUNICAÇÃO SOCIAL
# 1    2017   ALUNO DE GRADUAÇÃO       CIÊNCIAS ATUARIAIS
# 2    2017   ALUNO DE GRADUAÇÃO  ARQUITETURA E URBANISMO
# 3    2017   ALUNO DE GRADUAÇÃO         ENGENHARIA CIVIL
# 4    2017   ALUNO DE GRADUAÇÃO    CIÊNCIAS E TECNOLOGIA
# ..    ...                  ...                      ...
# 170  2019   ALUNO DE GRADUAÇÃO     ENGENHARIA AMBIENTAL
# 171  2019   ALUNO DE GRADUAÇÃO             FISIOTERAPIA
# 172  2019   ALUNO DE GRADUAÇÃO                  TURISMO
# 173  2018   ALUNO DE GRADUAÇÃO                   LETRAS
# 174  2020   ALUNO DE GRADUAÇÃO                 NUTRIÇÃO
#
#      QUANTIDADE_EMPRESTIMOS
# 0                      8773
# 1                      8560
# 2                      8451
# 3                      8427
# 4                      8393
# ..                      ...
# 170                       4
# 171                       3
# ...

# %%
emprestimos_tipo_usuario_curso_pivot = emprestimos_tipo_usuario_e_curso.pivot_table(
        index = 'CURSO',
        columns = ['ANO','TIPO_VINCULO_USUARIO'],
        values = 'QUANTIDADE_EMPRESTIMOS',
        fill_value = '-',
        aggfunc= sum,
        margins = True,
        margins_name = 'TOTAL',
)

# %%
emprestimos_tipo_usuario_curso_pivot
# Out:
# ANO                                                  2017  \
# TIPO_VINCULO_USUARIO                   ALUNO DE GRADUAÇÃO
# CURSO
# ADMINISTRAÇÃO                                      7792.0
# AGRONOMIA                                          7842.0
# ANÁLISE E DESENVOLVIMENTO DE SISTEMAS                19.0
# ARQUITETURA E URBANISMO                            8451.0
# ARTES CÊNICAS                                           -
# BIBLIOTECONOMIA                                    7680.0
# BIOINFORMÁTICA                                          -
# BIOMEDICINA                                        7588.0
# BIOQUÍMICA                                              -
# CIÊNCIA DA COMPUTAÇÃO                              7372.0
# CIÊNCIA E ENGENHARIA DE MATERIAIS                       -
# CIÊNCIA, TECNOLOGIA E INOVAÇÃO                          -
# CIÊNCIAS ATUARIAIS                                 8560.0
# CIÊNCIAS BIOLÓGICAS                                7708.0
# ...

# %% [markdown]
# #Dia 7

# %%
emprestimos_pos_graduacao_e_curso = emprestimos_tipo_usuario_e_curso.query("TIPO_VINCULO_USUARIO == 'ALUNO DE PÓS-GRADUAÇÃO' and ANO != 2020")
emprestimos_pos_graduacao_e_curso
# Out:
#       ANO    TIPO_VINCULO_USUARIO                                   CURSO  \
# 66   2017  ALUNO DE PÓS-GRADUAÇÃO                           ADMINISTRAÇÃO
# 67   2018  ALUNO DE PÓS-GRADUAÇÃO                  CIÊNCIAS ODONTOLÓGICAS
# 68   2017  ALUNO DE PÓS-GRADUAÇÃO                  ENGENHARIA DE SOFTWARE
# 69   2017  ALUNO DE PÓS-GRADUAÇÃO                       CIÊNCIAS DA SAÚDE
# 70   2017  ALUNO DE PÓS-GRADUAÇÃO          CIÊNCIA, TECNOLOGIA E INOVAÇÃO
# 71   2017  ALUNO DE PÓS-GRADUAÇÃO                        ENGENHARIA CIVIL
# 72   2017  ALUNO DE PÓS-GRADUAÇÃO                  CIÊNCIAS ODONTOLÓGICAS
# 73   2018  ALUNO DE PÓS-GRADUAÇÃO          CIÊNCIA, TECNOLOGIA E INOVAÇÃO
# 74   2017  ALUNO DE PÓS-GRADUAÇÃO       CIÊNCIA E ENGENHARIA DE MATERIAIS
# 75   2017  ALUNO DE PÓS-GRADUAÇÃO                              BIOQUÍMICA
# 76   2018  ALUNO DE PÓS-GRADUAÇÃO                           ADMINISTRAÇÃO
# 77   2017  ALUNO DE PÓS-GRADUAÇÃO                                  DESIGN
# ...

# %%
emprestimos_pos_graduacao_e_curso_pivot = emprestimos_pos_graduacao_e_curso.pivot_table(
        index = 'CURSO',
        columns = 'ANO',
        values = 'QUANTIDADE_EMPRESTIMOS'
)
emprestimos_pos_graduacao_e_curso_pivot
# Out:
# ANO                                     2017  2018  2019
# CURSO
# ADMINISTRAÇÃO                           2651  2388  1746
# ARQUITETURA E URBANISMO                 2295  1995  1867
# ARTES CÊNICAS                           2217  2162  1895
# BIOINFORMÁTICA                          2308  1990  1889
# BIOQUÍMICA                              2389  2021  2126
# CIÊNCIA E ENGENHARIA DE MATERIAIS       2404  2227  2100
# CIÊNCIA, TECNOLOGIA E INOVAÇÃO          2520  2451  2101
# CIÊNCIAS DA SAÚDE                       2524  2060  1874
# CIÊNCIAS ODONTOLÓGICAS                  2488  2612  2201
# DESIGN                                  2372  1906  1917
# ENGENHARIA CIVIL                        2519  2143  2057
# ENGENHARIA DE SOFTWARE                  2539  2280  1955
# FILOSOFIA                               2266  2141  1856
# GESTÃO DA INFORMAÇÃO E DO CONHECIMENTO  2364  1975  1828

# %%
previsao_2022 = pd.read_table('https://github.com/FranciscoFoz/7_Days_of_Code_Alura-Python-Pandas/raw/main/Dia_7-Apresentando_resultados_em_HTML/Dataset/previsao')
previsao_2022 = previsao_2022['curso previsao_2022'].str.split(' ',expand=True)
previsao_2022
# Out:
#                                          0     1
# 0                            administracao  1905
# 1                  arquitetura_e_urbanismo  1896
# 2                            artes_cenicas  1920
# 3                           bioinformatica  2302
# 4                               bioquimica  2090
# 5        ciencia_e_engenharia_de_materiais  2010
# 6            ciencia_tecnologia_e_inovacao  1960
# 7                        ciencias_da_saude  1730
# 8                   ciencias_odontologicas  2405
# 9                                   design  1900
# 10                        engenharia_civil  1920
# 11                     engenharia_software  1890
# 12                               filosofia  1903
# 13  gestao_da_informacao_e_do_conhecimento  1855

# %%
previsao_2022.index = emprestimos_pos_graduacao_e_curso_pivot.index

# %%
emprestimos_pos_graduacao_e_curso_pivot['2022'] = previsao_2022.iloc[:,1]

# %%
emprestimos_pos_graduacao_e_curso_pivot['2022'] = emprestimos_pos_graduacao_e_curso_pivot['2022'].astype('int')

# %%
emprestimos_pos_graduacao_e_curso_pivot
# Out:
# ANO                                     2017  2018  2019  2022
# CURSO
# ADMINISTRAÇÃO                           2651  2388  1746  1905
# ARQUITETURA E URBANISMO                 2295  1995  1867  1896
# ARTES CÊNICAS                           2217  2162  1895  1920
# BIOINFORMÁTICA                          2308  1990  1889  2302
# BIOQUÍMICA                              2389  2021  2126  2090
# CIÊNCIA E ENGENHARIA DE MATERIAIS       2404  2227  2100  2010
# CIÊNCIA, TECNOLOGIA E INOVAÇÃO          2520  2451  2101  1960
# CIÊNCIAS DA SAÚDE                       2524  2060  1874  1730
# CIÊNCIAS ODONTOLÓGICAS                  2488  2612  2201  2405
# DESIGN                                  2372  1906  1917  1900
# ENGENHARIA CIVIL                        2519  2143  2057  1920
# ENGENHARIA DE SOFTWARE                  2539  2280  1955  1890
# FILOSOFIA                               2266  2141  1856  1903
# GESTÃO DA INFORMAÇÃO E DO CONHECIMENTO  2364  1975  1828  1855

# %%
def diferenca_percentual_ano_anterior(x,y):
  return round(((x / y * 100) - 100),2)

# %%
percentual_2018 = diferenca_percentual_ano_anterior(emprestimos_pos_graduacao_e_curso_pivot.iloc[:,1],emprestimos_pos_graduacao_e_curso_pivot.iloc[:,0])
percentual_2019 = diferenca_percentual_ano_anterior(emprestimos_pos_graduacao_e_curso_pivot.iloc[:,2],emprestimos_pos_graduacao_e_curso_pivot.iloc[:,1])
percentual_2022 = diferenca_percentual_ano_anterior(emprestimos_pos_graduacao_e_curso_pivot.iloc[:,3],emprestimos_pos_graduacao_e_curso_pivot.iloc[:,2])

# %%
percentual = pd.DataFrame({'2018':percentual_2018,
                           '2019':percentual_2019,
                           '2022':percentual_2022})
percentual
# Out:
#                                          2018   2019   2022
# CURSO
# ADMINISTRAÇÃO                           -9.92 -26.88   9.11
# ARQUITETURA E URBANISMO                -13.07  -6.42   1.55
# ARTES CÊNICAS                           -2.48 -12.35   1.32
# BIOINFORMÁTICA                         -13.78  -5.08  21.86
# BIOQUÍMICA                             -15.40   5.20  -1.69
# CIÊNCIA E ENGENHARIA DE MATERIAIS       -7.36  -5.70  -4.29
# CIÊNCIA, TECNOLOGIA E INOVAÇÃO          -2.74 -14.28  -6.71
# CIÊNCIAS DA SAÚDE                      -18.38  -9.03  -7.68
# CIÊNCIAS ODONTOLÓGICAS                   4.98 -15.74   9.27
# DESIGN                                 -19.65   0.58  -0.89
# ENGENHARIA CIVIL                       -14.93  -4.01  -6.66
# ENGENHARIA DE SOFTWARE                 -10.20 -14.25  -3.32
# FILOSOFIA                               -5.52 -13.31   2.53
# GESTÃO DA INFORMAÇÃO E DO CONHECIMENTO -16.46  -7.44   1.48

# %%
percentual.reset_index(inplace=True)

# %%
percentual.columns = percentual.columns.str.capitalize()
percentual.Curso = percentual.Curso.str.capitalize()

# %%
th_props = [
  ('font-size', '1.4rem'),
  ('text-align', 'center'),
  ('font-weight', 'bold'),
  ('color', 'whitesmoke'),
  ('background-color', '#001692'),
  ('border-radius', '0.25rem'),
  ('box-shadow','0 0 1rem gray')
  ]

td_props = [
  ('font-size', '1rem'),
  ('padding','0.5rem'),
  ('text-align', 'left'),
  ('font-weight', 'bold'),
  ('border-bottom','0.1rem solid lightgray')
  ]

styles = [
  dict(selector="th", props=th_props),
  dict(selector="td", props=td_props)
  ]

# %%
percentual.style.text_gradient(cmap='RdYlGn',low=1, axis=1,vmax=0.1,vmin=0)\
                              .format('{:.2f} %',subset=['2018','2019','2022'])\
                              .hide_index()\
                              .set_table_styles(styles)\
                              .to_html('teste.html',doctype_html =True,
                                       table_attributes='ALIGN=LEFT WIDTH=50% CELLSPACING = 5')
